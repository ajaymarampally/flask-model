# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_yes_no = pd.read_csv(r'/Users/anuragsangem/Downloads/Untitled form.csv')
df_response=pd.read_excel(r'/Users/anuragsangem/Downloads/(Responses).xlsx')

# %%
df_yes_no.head()
# Out:
#                    Timestamp  What is your GRE score?  \
# 0  2023/03/23 1:18:43 PM AST                      310
# 1  2023/03/23 1:20:52 PM AST                      325
# 2  2023/03/23 1:24:32 PM AST                      328
# 3  2023/03/23 1:25:00 PM AST                      315
# 4  2023/03/23 1:33:23 PM AST                      312
#
#    What is your TOEFL score or IELTS score?  \
# 0                                       7.5
# 1                                     110.0
# 2                                     108.0
# 3                                      98.0
# 4                                     105.0
#
#    On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
# ...

# %%
df_response.head()
# Out:
#                 Timestamp Admitted to IU?  What is your GRE score?  \
# 0 2023-03-23 13:18:43.883             Yes                    310.0
# 1 2023-03-23 13:20:52.907             Yes                    325.0
# 2 2023-03-23 13:24:32.573             Yes                    328.0
# 3 2023-03-23 13:25:00.002             Yes                    315.0
# 4 2023-03-23 13:33:23.663             Yes                    312.0
#
#    What is your TOEFL score or IELTS score?  \
# 0                                       7.5
# 1                                     110.0
# 2                                     108.0
# 3                                      98.0
# 4                                     105.0
#
#    On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?  \
# 0                                                4.0
# 1                                                4.0
# 2                                                3.0
# ...

# %%
x_yes = df_response['What is your GRE score?']
x_no=df_yes_no[df_yes_no['Admitted to IU?']=='No']['What is your GRE score?']
plt.plot(x_yes, label = "Admits GRE")
plt.plot(x_no, label = "Rejects GRE")

plt.legend()
plt.show()

# We can see a particular window of rejects having GRE score from 290-310
#This clearly shows the admit/ reject status doesnt stroctly depend on the GRE score

# %%
mean_GRE_yes = df_response['What is your GRE score?'].mean()
mean_GRE_no=df_yes_no[df_yes_no['Admitted to IU?']==0]['What is your GRE score?'].mean()

mean_dict={'mean_GRE_admit':mean_GRE_yes , 'mean_GRE_no':mean_GRE_no}
mean_score = list(mean_dict.keys())
values = list(mean_dict.values())

plt.bar(mean_score, values, color ='blue',width = 0.4)
 
plt.xlabel("Admit/reject")
plt.ylabel("Mean GRE Score")
plt.title("Mean GRE scores for Admits/Rejects at IU")
plt.show()

#we can get no relevant conclusion by only GRE score

# %%
#We can observe undergrad GPA is a crucial factor in deciding admit to IU Computer science and informatics departments grad program

mean_GPA_yes = df_response['What is your TOEFL score or IELTS score?'].mean()
mean_GPA_no=df_yes_no[df_yes_no['Admitted to IU?']==0]['What is your TOEFL score or IELTS score?'].mean()

mean_dict={'mean_GPA_admit':mean_GPA_yes , 'mean_GPA_no':mean_GPA_no}
mean_score = list(mean_dict.keys())
values = list(mean_dict.values())

plt.bar(mean_score, values, color ='blue',width = 0.2)
 
plt.xlabel("Admit/reject")
plt.ylabel("Mean GPA")
plt.title("Mean GPA scores for Admits/Rejects at IU")
plt.show()

# %%
df_response.head()
# Out:
#                 Timestamp Admitted to IU?  What is your GRE score?  \
# 0 2023-03-23 13:18:43.883             Yes                    310.0
# 1 2023-03-23 13:20:52.907             Yes                    325.0
# 2 2023-03-23 13:24:32.573             Yes                    328.0
# 3 2023-03-23 13:25:00.002             Yes                    315.0
# 4 2023-03-23 13:33:23.663             Yes                    312.0
#
#    What is your TOEFL score or IELTS score?  \
# 0                                       7.5
# 1                                     110.0
# 2                                     108.0
# 3                                      98.0
# 4                                     105.0
#
#    On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?  \
# 0                                                4.0
# 1                                                4.0
# 2                                                3.0
# ...

# %%
x_yes = df_response['What is your undergraduate GPA out of 10?']
x_no=df_yes_no[df_yes_no['Admitted to IU?']=='No']['What is your undergraduate GPA out of 10?']
plt.plot(x_yes, label = "Admits GPA")
plt.plot(x_no, label = "Rejects GPA")

plt.legend()
plt.show()

#We can see a smiliar window for rejects but there is lot of common admitted people with the similar gpa , hence we can conclude GPA solely is not responsible for 
#admits rejects

# %%
df_yes_no.corr()

#this shows that the admit . reject chane highly depends on undergrad GPA , GRE score , LOR strength
# Out:
#                                                     What is your GRE score?  \
# What is your GRE score?                                            1.000000
# What is your TOEFL score or IELTS score?                           0.193200
# On a scale of 1 to 5, how would you rate the st...                 0.261765
# On a scale of 1 to 5, how would you rate the st...                 0.308758
# What is your undergraduate GPA out of 10?                          0.556851
# How many publications or research experiences d...                 0.169604
# Admitted to IU?                                                    0.691478
#
#                                                     What is your TOEFL score or IELTS score?  \
# What is your GRE score?                                                             0.193200
# What is your TOEFL score or IELTS score?                                            1.000000
# ...

# %%
df_yes_no['How many publications or research experiences do you have?']=df_yes_no['How many publications or research experiences do you have?'].fillna(value=mean_value)

# %%
df_yes_no['Admitted to IU?']=df_yes_no['Admitted to IU?'].map({'Yes':1,'No':0})

# %%
# admit rate for each department
df_admit_count=pd.DataFrame(df_response.groupby('What program have you applied for?').aggregate({'Admitted to IU?':'count'}))
#We can see the computer science department have the most admits (in the given data)
# Out:
#                                     Admitted to IU?
# What program have you applied for?
# Computer Science                                 31
# Data Science                                     16
# Human Computer Interaction                        4
# Information Systems                               7
# Secure Computing                                  1

# %%
df_admit_count=pd.DataFrame(df_response.groupby('What program have you applied for?').aggregate(
    {'Admitted to IU?':'count'}))
df_admit_count=df_admit_count.reset_index('What program have you applied for?')
df_admit_count['Ratio of admit among all admits']=df_admit_count['Admitted to IU?']/60
df_admit_count
# Out:
#                                     Admitted to IU?
# What program have you applied for?
# Computer Science                                 31
# Data Science                                     16
# Human Computer Interaction                        4
# Information Systems                               7
# Secure Computing                                  1

# %%
#feature engineering - admit probability from the collected admits data
df_admit_count['Ratio of admit among all admits']=df_admit_count['Admitted to IU?']/60

# %%
df_admit_count
# Out:
#   What program have you applied for?  Admitted to IU?  \
# 0                   Computer Science               31
# 1                       Data Science               16
# 2         Human Computer Interaction                4
# 3                Information Systems                7
# 4                   Secure Computing                1
#
#    Ratio of admit among all admits
# 0                         0.516667
# 1                         0.266667
# 2                         0.066667
# 3                         0.116667
# 4                         0.016667

# %%
#Data scrapped from admitsfyi - website

# %%
df_1 = pd.read_csv(r'/Users/anuragsangem/Downloads/admission_data (1).csv')

# %%
df_1.shape
# Out:
# (100, 14)

# %%
#Data collected by circualting a google doc among the admitted students at IU
df_3 = pd.read_csv(r'/Users/anuragsangem/Downloads/Untitled form.csv')

# %%
df_1.head()
# Out:
#                         University  Status      Target major       Year GRE_Q  \
# 0  Indiana University, Bloomington  Reject  Computer Science  Fall 2016   166
# 1  Indiana University, Bloomington   Admit  Computer Science  Fall 2015   170
# 2  Indiana University, Bloomington  Reject               MIS  Fall 2018   157
# 3  Indiana University, Bloomington   Admit      Data Science  Fall 2019   170
# 4  Indiana University, Bloomington   Admit      Data Science  Fall 2018   168
#
#   GRE_V GRE_AWA GRE_TOTAL IELTS_or_TOEFL  \
# 0   144       3       310             92
# 1   148       3       318             99
# 2   148     NaN       305            103
# 3   150       4       320            105
# 4   148       4       316            110
#
#                                              College              Department  \
# 0  Shri guru govind singh college of engineering,...        Computer Science
# 1                                                NaN                     NaN
# ...

# %%
df_3
# Out:
#                      Timestamp  What is your GRE score?  \
# 0    2023/03/23 1:18:43 PM AST                      310
# 1    2023/03/23 1:20:52 PM AST                      325
# 2    2023/03/23 1:24:32 PM AST                      328
# 3    2023/03/23 1:25:00 PM AST                      315
# 4    2023/03/23 1:33:23 PM AST                      312
# 5    2023/03/23 2:31:40 PM AST                      315
# 6    2023/03/23 2:34:05 PM AST                      318
# 7    2023/03/23 3:20:09 PM AST                      307
# 8   2023/03/23 10:05:45 PM AST                      331
# 9   2023/03/24 12:39:24 PM AST                      314
# 10   2023/03/25 5:32:18 PM AST                      310
# 11   2023/03/25 5:32:46 PM AST                      303
# 12   2023/03/25 5:33:31 PM AST                      320
# 13   2023/03/25 5:34:08 PM AST                      317
# 14   2023/03/25 5:35:03 PM AST                      310
# 15   2023/03/25 5:35:31 PM AST                      310
# ...

# %%
df_3.columns
# Out:
# Index(['Timestamp', 'What is your GRE score?',
#        'What is your TOEFL score or IELTS score?',
#        'On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?',
#        'On a scale of 1 to 5, how would you rate the strength of your Letters of Recommendation?',
#        'What is your undergraduate GPA out of 10?',
#        'How many publications or research experiences do you have?',
#        'Which course you got admitted into?',
#        'What program have you applied for?', 'Admitted to IU?'],
#       dtype='object')

# %%
#reqiuired columns in df_3
columns=['What is your GRE score?','What is your TOEFL score or IELTS score?','On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?',
        'On a scale of 1 to 5, how would you rate the strength of your Letters of Recommendation?','What is your undergraduate GPA out of 10?',
        'How many publications or research experiences do you have?','Which course you got admitted into?','What program have you applied for?','Admitted to IU?']

# %%
df_3_filtered=df_3[columns]

# %%
df_3_filtered.rename(columns={'What is your GRE score?':'GRE_TOTAL',
                              'What is your TOEFL score or IELTS score?':'IELTS_or_TOEFL',
                              'On a scale of 1 to 5, how would you rate the strength of your Letters of Recommendation?':'SOP_Strength',
                              'What is your undergraduate GPA out of 10?':'Grade',
                              'How many publications or research experiences do you have?':'Publications',
                              'What program have you applied for?':'Target major'},inplace=True)
# Out:
# /var/folders/j2/qrfkkpz51h7fdg0g8v5r67p80000gn/T/ipykernel_81558/491410098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_filtered.rename(columns={'What is your GRE score?':'GRE_TOTAL',

# %%
df_3_filtered.rename(columns={'Admitted to IU?':'Status'},inplace=True)
# Out:
# /var/folders/j2/qrfkkpz51h7fdg0g8v5r67p80000gn/T/ipykernel_81558/4035025111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_filtered.rename(columns={'Admitted to IU?':'Status'},inplace=True)

# %%
df_3_filtered.head()
# Out:
#    GRE_TOTAL  IELTS_or_TOEFL  \
# 0        310             7.5
# 1        325           110.0
# 2        328           108.0
# 3        315            98.0
# 4        312           105.0
#
#    On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    SOP_Strength  Grade  Publications Which course you got admitted into?  \
# 0             4   8.72           1.0                            Master's
# 1             4   8.47           NaN                            Master's
# 2             1   8.30           0.0                            Master's
# 3             4   8.80           1.0                            Master's
# ...

# %%
df_3_filtered['Status'] = df_3_filtered['Status'].map({'Yes': 'Admit', 'No': 'Reject'})
# Out:
# /var/folders/j2/qrfkkpz51h7fdg0g8v5r67p80000gn/T/ipykernel_81558/2811511774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_filtered['Status'] = df_3_filtered['Status'].map({'Yes': 'Admit', 'No': 'Reject'})

# %%
df_3_filtered.head()
df_3_filtered.drop('On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?',axis=1,inplace=True)
# Out:
# /var/folders/j2/qrfkkpz51h7fdg0g8v5r67p80000gn/T/ipykernel_81558/1508704412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_filtered.drop('On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?',axis=1,inplace=True)

# %%
df_3_filtered.columns
# Out:
# Index(['GRE_TOTAL', 'IELTS_or_TOEFL',
#        'On a scale of 1 to 5, how would you rate the strength of your Statement of Purpose?',
#        'SOP_Strength', 'Grade', 'Publications',
#        'Which course you got admitted into?', 'Target major', 'Status'],
#       dtype='object')

# %%
df_1_merged=df_1[df_1['University']=='Indiana University, Bloomington']

# %%
df_1_merged.iloc[0:50]
# Out:
#                          University  Status                   Target major  \
# 0   Indiana University, Bloomington  Reject               Computer Science
# 1   Indiana University, Bloomington   Admit               Computer Science
# 2   Indiana University, Bloomington  Reject                            MIS
# 3   Indiana University, Bloomington   Admit                   Data Science
# 4   Indiana University, Bloomington   Admit                   Data Science
# 5   Indiana University, Bloomington  Reject                   Data Science
# 6   Indiana University, Bloomington   Admit               Computer Science
# 7   Indiana University, Bloomington   Admit                            MIS
# 8   Indiana University, Bloomington   Admit                            MIS
# 9   Indiana University, Bloomington   Admit               Computer Science
# 11  Indiana University, Bloomington   Admit                            MIS
# ...

# %%
columns2=['Status', 'Target major'
       ,'GRE_TOTAL', 'IELTS_or_TOEFL',
       'Grade', 'Publications']

# %%
df_1_merged=df_1_merged[columns2]

# %%
df_3_filtered=df_3_filtered[columns2]

# %%
df_merged_final=pd.concat([df_1_merged,df_3_filtered])

# %%
df_merged_final
# Out:
#     Status         Target major GRE_TOTAL IELTS_or_TOEFL Grade Publications
# 0   Reject     Computer Science       310             92  8.59          NaN
# 1    Admit     Computer Science       318             99   NaN          NaN
# 2   Reject                  MIS       305            103  9.59            0
# 3    Admit         Data Science       320            105  9.14          NaN
# 4    Admit         Data Science       316            110  61.7            1
# ..     ...                  ...       ...            ...   ...          ...
# 54  Reject     Computer Science       309            6.0   6.9          1.0
# 55  Reject  Information Systems       300            7.0   7.9          1.0
# 56  Reject         Data Science       305            7.5   6.9          1.0
# 57   Admit     Secure Computing       310            7.5   8.9          1.0
# 58   Admit     Computer Science       309            7.5   9.3          2.0
#
# [149 rows x 6 columns]

# %%
df_merged_final['Status'].value_counts()
# Out:
# Admit     98
# Reject    51
# Name: Status, dtype: int64

# %%
df_merged_final['Target major'].value_counts()
# Out:
# Computer Science                 77
# Data Science                     41
# MIS                              17
# Information Systems               7
# Human Computer Interaction        4
# Information & Library Science     1
# Cyber Security                    1
# Secure Computing                  1
# Name: Target major, dtype: int64

# %%
#Data cleaning
df_merged_final['Publications'].fillna(0,inplace=True)

# %%
df_merged_final['IELTS_or_TOEFL'].fillna('6.5',inplace=True) #Filling missing values with mode of the column

# %%
df_merged_final = df_merged_final.astype({'IELTS_or_TOEFL':'float64'})
df_merged_final = df_merged_final.astype({'Grade':'float64'})

# %%
df_merged_final['Grade'] = df_merged_final['Grade'].fillna(df_merged_final['Grade'].median())

# %%
df_merged_final.isnull().sum() #Fixed all the missing values
# Out:
# Status            0
# Target major      0
# GRE_TOTAL         0
# IELTS_or_TOEFL    0
# Grade             0
# Publications      0
# dtype: int64

# %%
df_merged_final.head()
# Out:
#    Status      Target major GRE_TOTAL  IELTS_or_TOEFL  Grade Publications
# 0  Reject  Computer Science       310            92.0   8.59            0
# 1   Admit  Computer Science       318            99.0   8.50            0
# 2  Reject               MIS       305           103.0   9.59            0
# 3   Admit      Data Science       320           105.0   9.14            0
# 4   Admit      Data Science       316           110.0  61.70            1

# %%
df_merged_final['Target major'].dtypes
# Out:
# dtype('O')

# %%
df_merged_final
# Out:
#     Status         Target major GRE_TOTAL  IELTS_or_TOEFL  Grade Publications
# 0   Reject     Computer Science       310            92.0   8.59            0
# 1    Admit     Computer Science       318            99.0   8.50            0
# 2   Reject                  MIS       305           103.0   9.59            0
# 3    Admit         Data Science       320           105.0   9.14            0
# 4    Admit         Data Science       316           110.0  61.70            1
# ..     ...                  ...       ...             ...    ...          ...
# 54  Reject     Computer Science       309             6.0   6.90          1.0
# 55  Reject  Information Systems       300             7.0   7.90          1.0
# 56  Reject         Data Science       305             7.5   6.90          1.0
# 57   Admit     Secure Computing       310             7.5   8.90          1.0
# 58   Admit     Computer Science       309             7.5   9.30          2.0
#
# [149 rows x 6 columns]

# %%
df_merged_final_copy=df_merged_final.copy(deep=True)

# %%
df_merged_final_copy.to_csv(r'/Users/anuragsangem/Desktop/df_merged_final.csv')

# %%
# Convert the 'Target_Major' column to one-hot encoding using pd.get_dummies()
#We are using One hot encoding instead of label encoding because we want to store the information of the strings when the user gives input

import joblib
X = df_merged_final_copy.drop('Status', axis=1)
y = df_merged_final_copy['Status']

# One-hot encode the categorical columns
categorical_cols = ['Target major']
X = pd.get_dummies(X, columns=categorical_cols)

one_hot_encoder = joblib.dump(X.columns, 'one_hot_encoder.joblib')

# %%
one_hot_encoder #we will save this to use in the integration part of the project
# Out:
# ['one_hot_encoder.joblib']

# %%
#Model building - we are using random forest because we also have to get the probability of a classification


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


# Convert the 'Target_Major' column to one-hot encoding using pd.get_dummies()
df_merged_final = pd.get_dummies(df_merged_final, columns=['Target major'])

# Split your data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_merged_final.drop('Status', axis=1), df_merged_final['Status'], test_size=0.2, random_state=42)

# Train a random forest classifier on your training data
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Make predictions on your test data and compute accuracy
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8333333333333334

# %% [markdown]
# # Random decision tree viz in the forest we generated

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Set the font size for the plot
plt.rcParams.update({'font.size': 20})

# Extract a single decision tree from the random forest
tree = clf.estimators_[0]

# Plot the tree
fig, ax = plt.subplots(figsize=(50, 30))
plot_tree(tree, ax=ax, feature_names=X_train.columns, class_names=['Reject', 'Admit'], fontsize=20)

# Save the plot as an SVG file
plt.savefig('tree.svg', format='svg', dpi=1200)

# %% [markdown]
# # As we got around 83% acuracy on the test set- which is really good given we have very less data
# # We are training the model on the entire data and saving the model

# %%
df_merged_final.head()
# Out:
#    Status GRE_TOTAL  IELTS_or_TOEFL  Grade Publications  \
# 0  Reject       310            92.0   8.59            0
# 1   Admit       318            99.0   8.50            0
# 2  Reject       305           103.0   9.59            0
# 3   Admit       320           105.0   9.14            0
# 4   Admit       316           110.0  61.70            1
#
#    Target major_Computer Science  Target major_Cyber Security  \
# 0                              1                            0
# 1                              1                            0
# 2                              0                            0
# 3                              0                            0
# 4                              0                            0
#
#    Target major_Data Science  Target major_Human Computer Interaction  \
# 0                          0                                        0
# 1                          0                                        0
# ...

# %%
df_merged_final.iloc[:,1:5]
# Out:
#    GRE_TOTAL  IELTS_or_TOEFL  Grade Publications
# 0        310            92.0   8.59            0
# 1        318            99.0   8.50            0
# 2        305           103.0   9.59            0
# 3        320           105.0   9.14            0
# 4        316           110.0  61.70            1
# ..       ...             ...    ...          ...
# 54       309             6.0   6.90          1.0
# 55       300             7.0   7.90          1.0
# 56       305             7.5   6.90          1.0
# 57       310             7.5   8.90          1.0
# 58       309             7.5   9.30          2.0
#
# [149 rows x 4 columns]

# %%
X=df_merged_final.iloc[:,1:5]
y=df_merged_final['Status']
# Train a random forest classifier on your training data
clf_final = RandomForestClassifier(n_estimators=100, random_state=42)
clf_final.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import pickle
pickle.dump(clf_final,open('model2.pkl','wb'))

# %%
from joblib import dump

# Save the trained model to a file
dump(clf_final, 'model.joblib')
# Out:
# ['model.joblib']

# %%
#Trying KNN

from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=2)

# %%
knn_model.fit(X, y)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
test_preds=knn_model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [411], in <cell line: 1>()
# ----> 1 test_preds=knn_model.predict(X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_regression.py:238, in KNeighborsRegressor.predict(self, X)
#     235     _y = _y.reshape((-1, 1))
#     237 if weights is None:
# --> 238     y_pred = np.mean(_y[neigh_ind], axis=1)
#     239 else:
#     240     y_pred = np.empty((X.shape[0], _y.shape[1]), dtype=np.float64)
#
# File <__array_function__ internals>:5, in mean(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440, in mean(a, axis, dtype, out, keepdims, where)
#    3437     else:
#    3438         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3440 return _methods._mean(a, axis=axis, dtype=dtype,
#    3441                       out=out, **kwargs)
#
# ...

# %%
import seaborn as sns
cmap = sns.cubehelix_palette(as_cmap=True)
f, ax = plt.subplots()
points = ax.scatter( X, y, c=test_preds, s=50, cmap=cmap)
f.colorbar(points)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [410], in <cell line: 4>()
#       2 cmap = sns.cubehelix_palette(as_cmap=True)
#       3 f, ax = plt.subplots()
# ----> 4 points = ax.scatter( X, y, c=test_preds, s=50, cmap=cmap)
#       5 f.colorbar(points)
#       6 plt.show()
#
# NameError: name 'test_preds' is not defined

# %%
#!conda install -c conda-forge xgboost
# !pip install xgboost
# Out:
# ^C
# Traceback (most recent call last):
#   File "/opt/homebrew/bin/pip", line 5, in <module>
#     from pip._internal.cli.main import main
#   File "/opt/homebrew/lib/python3.11/site-packages/pip/_internal/cli/main.py", line 9, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/opt/homebrew/lib/python3.11/site-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/opt/homebrew/lib/python3.11/site-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "/opt/homebrew/lib/python3.11/site-packages/pip/_internal/build_env.py", line 15, in <module>
#     from pip._vendor.packaging.requirements import Requirement
#   File "/opt/homebrew/lib/python3.11/site-packages/pip/_vendor/packaging/requirements.py", line 23, in <module>
#     from .markers import MARKER_EXPR, Marker
# ...

# %%
model = XGBClassifier(eval_metric = "mlogloss")
model.fit(X_train, y_train)
y_predict = model.predict_proba(X_test)
print(y_predict)

# %% [raw]
# As the user eill be inputting the Target_Major in the form of a string such as 'Data Science' , 'Computer Science' etc , we need a mechanism to pre process this information and feed it to the model correctly

# %%
# Load the saved model
import joblib

model = joblib.load('model.joblib')

# Load the one-hot encoder
one_hot_encoder = joblib.load('one_hot_encoder.joblib')

# Define a function to preprocess the user input
# def preprocess_input( gre_total, ielts_or_toefl, grade, publications):
#     input_data = pd.DataFrame({
#         'GRE_TOTAL': [gre_total],
#         'IELTS_or_TOEFL': [ielts_or_toefl],
#         'Grade': [grade],
#         'Publications': [publications]
#     })
#     input_data[target_major] = 1
#     input_data = input_data.reindex(columns=one_hot_encoder, fill_value=0)
#     return input_data


# Define a function to predict the admission probability based on user input
def predict_admission(gre_total, ielts_or_toefl, grade, publications):
    input_data = np.array([gre_total, ielts_or_toefl, grade, publications]).reshape(1,4)
    probability_admit = clf_final.predict_proba(input_data)[0][0]
    return probability_admit

# %%
# Test the function with sample input

gre_total = 300
ielts_or_toefl = 8
grade = 8.0
publications = 0


probability_admit = predict_admission(gre_total, ielts_or_toefl, grade, publications)


# Print the output
print('The probability of admission is:', probability_admit)
# Out:
# The probability of admission is: 0.04
# /Users/anuragsangem/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
del(target_major)

# %%
from flask import Flask, jsonify, request
from joblib import load

# Load the trained model from a file
clf = load('model.joblib')

# Create a Flask application
app = Flask(__name__)

# Define a route for the prediction API
@app.route('/predict', methods=['POST'])
def predict():
    # Extract the input data from the request
    data = request.get_json()
    gre_total = data['GRE Score']
    ielts_or_toefl = data['English Proficiency']
    grade = data['Undergraduation GPA']
    publications = data['Number of relevant publications']

    
    # Make a prediction using the trained model
    X = [[target_major, gre_total, ielts_or_toefl, grade, publications]]
    y_pred = clf.predict_proba(X)
    
    # Return the prediction as a JSON response
    return jsonify({'probability_admit': y_pred[0, 1]})

# Start the Flask application
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (fsevents)
# Traceback (most recent call last):
#   File "/Users/anuragsangem/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/anuragsangem/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.initialize(argv)
#   File "/Users/anuragsangem/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 88, in inner
#     return method(app, *args, **kwargs)
#   File "/Users/anuragsangem/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 632, in initialize
#     self.init_sockets()
# ...

# %%
#Ideas

1)Add a flag if the user inputs invalid input to let them know its incorrect
2)Try to standardize the IELTS/TOEFEL column and write a function to convert scale of TOEFEL to IELTS range from the user
3)SPark

# %%
#Recommender system
#using kaggle and US news data

# %%
df=pd.read_csv(r'/Users/anuragsangem/Downloads/report_template-1/University-Recommendation-System-main/src/data/Prepared MS University Data.csv')

# %%
df.head()
# Out:
#   Major  researchExp  industryExp  toeflScore  GRE_V  GRE_Q  GRE_AWA  CGPA  \
# 0   MIS          0.0         66.0   94.000000    146    157      3.0  3.42
# 1   MIS          0.0          0.0   81.000000    140    170      2.5  2.55
# 2   MIS          0.0          0.0  104.212515    140    157      3.0  2.30
# 3   MIS          0.0          0.0  104.000000    150    161      4.5  2.80
# 4   MIS          0.0          0.0   95.000000    147    156      3.0  2.30
#
#                         University
# 0  Worcester Polytechnic Institute
# 1  Worcester Polytechnic Institute
# 2  Worcester Polytechnic Institute
# 3  Worcester Polytechnic Institute
# 4  Worcester Polytechnic Institute

# %%
df['Major'].value_counts()
# Out:
# Computer Science                       16957
# Speech Language Pathology               6075
# Electrical Engineering                  4333
# MIS                                     3788
# Civil Engineering                       2479
# Mechanical Engineering                  2464
# Electronics and Communication           2150
# Industrial Engineering                  1460
# Information Systems                     1292
# Statistics                               756
# Urban Planning                           726
# Public Policy                            707
# Business Analytics                       664
# Architecture                             661
# Engineering Management                   622
# Electrical and Computer Engineering      536
# Economics                                511
# Aerospace Engineering                    437
# Biomedical Engineering                   436
# Public Health                            432
# English                                  430
# ...

# %%
Selected_Majors = ['Computer Science','MIS','Information Systems ','Business Analytics']

# %%
df_filtered=df[df['Major'].isin(Selected_Majors)]

# %%
df_filtered.to_csv('Desktop/Prepared MS University Data_Filtered.csv')

# %%
/Users/anuragsangem/Downloads/report_template-1/University-Recommendation-System-main/src/data/Prepared MS University Data.csv", header=True, inferSchema=True)

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
import pickle

# %%
# Create a Spark session
spark = SparkSession.builder.appName("ECC Project - UniversityClustering").getOrCreate()
# Out:
# 23/04/27 22:54:51 WARN Utils: Your hostname, Anurags-MacBook-Air-3.local resolves to a loopback address: 127.0.0.1; using 10.0.0.95 instead (on interface en0)
# 23/04/27 22:54:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/27 22:54:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#Universities in the US only

data = spark.read.csv("Desktop/Prepared MS University Data_Filtered.csv", header=True, inferSchema=True)

# %%
data.show(10)
# Out:
# 23/04/28 00:54:31 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
#  Schema: _c0, Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# Expected: _c0 but found:
# CSV file: file:///Users/anuragsangem/Desktop/Prepared%20MS%20University%20Data_Filtered.csv
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+
# |_c0|           Major|researchExp|industryExp|toeflScore|GRE_V|GRE_Q|GRE_AWA|CGPA|          University|
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+
# |459|Computer Science|        0.0|        0.0|     113.0|  148|  170|    4.5|3.26|University of Wis...|
# |461|Computer Science|        0.0|        0.0|     117.0|  160|  170|    5.5|3.87|University of Wis...|
# ...

# %%
#Universities in the US only
from pyspark.sql.functions import col

# assuming you have a DataFrame called "df"
data = data.withColumn("GRE_Total", col("GRE_V") + col("GRE_Q"))

# %%
#Converting CGPA to the scale of 10
data = data.withColumn("CGPA2", (col("CGPA")*10)/4)

# %%
data.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Major: string (nullable = true)
#  |-- researchExp: double (nullable = true)
#  |-- industryExp: double (nullable = true)
#  |-- toeflScore: double (nullable = true)
#  |-- GRE_V: integer (nullable = true)
#  |-- GRE_Q: integer (nullable = true)
#  |-- GRE_AWA: double (nullable = true)
#  |-- CGPA: double (nullable = true)
#  |-- University: string (nullable = true)
#  |-- GRE_Total: integer (nullable = true)
#  |-- CGPA2: double (nullable = true)

# %%
data.show(5)
# Out:
# 23/04/28 01:16:54 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
#  Schema: _c0, Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# Expected: _c0 but found:
# CSV file: file:///Users/anuragsangem/Desktop/Prepared%20MS%20University%20Data_Filtered.csv
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+---------+-----------------+
# |_c0|           Major|researchExp|industryExp|toeflScore|GRE_V|GRE_Q|GRE_AWA|CGPA|          University|GRE_Total|            CGPA2|
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+---------+-----------------+
# |459|Computer Science|        0.0|        0.0|     113.0|  148|  170|    4.5|3.26|University of Wis...|      318|8.149999999999999|
# ...

# %%
value_counts = data.groupBy("University").count()
value_counts.show()
# Out:
# +--------------------+-----+
# |          University|count|
# +--------------------+-----+
# | New York University|  354|
# |Texas A&M Interna...|  415|
# |State University ...|  525|
# |Northeastern Univ...| 1148|
# |Carnegie Mellon U...|  707|
# |University of Cin...|  476|
# | Columbia University|  250|
# |University of Sou...| 1056|
# |University of Mas...|  183|
# |University of Tex...| 2004|
# |University of Was...|  137|
# |Indiana Universit...|  105|
# |State University ...| 1122|
# |University of Col...|  168|
# |New Jersey Instit...|  337|
# |University of Flo...|  629|
# |North Carolina St...|  913|
# |Stevens Institute...|  178|
# |University of Ari...|  472|
# |Arizona State Uni...| 1225|
# +--------------------+-----+
# only showing top 20 rows

# %%
from pyspark.ml.classification import RandomForestClassifier
# Load the data as a PySpark dataframe

# Convert the string column 'University admitted' to numerical label using StringIndexer
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCol='University', outputCol='label')
data = indexer.fit(data).transform(data)

# Assemble the input features as a vector
assembler = VectorAssembler(inputCols=['researchExp', 'toeflScore', 'GRE_Total','CGPA2'], outputCol='features')
data = assembler.transform(data)

# %%
# Index the University column
indexer = StringIndexer(inputCol="University", outputCol="UniversityIndex")
indexed = indexer.fit(data).transform(data)

# %%
indexed.show(10)
# Out:
# 23/04/28 01:24:14 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
#  Schema: _c0, Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# Expected: _c0 but found:
# CSV file: file:///Users/anuragsangem/Desktop/Prepared%20MS%20University%20Data_Filtered.csv
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+---------+-----------------+-----+--------------------+---------------+
# |_c0|           Major|researchExp|industryExp|toeflScore|GRE_V|GRE_Q|GRE_AWA|CGPA|          University|GRE_Total|            CGPA2|label|            features|UniversityIndex|
# +---+----------------+-----------+-----------+----------+-----+-----+-------+----+--------------------+---------+-----------------+-----+--------------------+---------------+
# ...

# %%
# Import required libraries
# Index the University column
indexer = StringIndexer(inputCol="University", outputCol="UniversityIndex")
indexed = indexer.fit(data).transform(data)

# Assemble the feature vector
assembler = VectorAssembler(inputCols=["researchExp", "toeflScore", "GRE_Total", "UniversityIndex"], outputCol="features")
data = assembler.transform(indexed)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Split the data into training and testing sets
(trainingData, testData) = data.randomSplit([0.7, 0.3])

# Train a random forest classifier
rf = RandomForestClassifier(labelCol="UniversityIndex", featuresCol="features", numTrees=10,maxBins=50)
pipeline = Pipeline(stages=[rf])
model = pipeline.fit(trainingData)


# Make predictions on the test data
predictions = model.transform(testData)

# Evaluate the performance of the classifier
evaluator = MulticlassClassificationEvaluator(labelCol="UniversityIndex", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)

# Print the accuracy of the classifier
print("Test Error = %g" % (1.0 - accuracy))
# Out:
# 23/04/28 01:28:24 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
#  Schema: _c0, Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# Expected: _c0 but found:
# CSV file: file:///Users/anuragsangem/Desktop/Prepared%20MS%20University%20Data_Filtered.csv
# 23/04/28 01:28:24 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
#  Schema: _c0, Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# Expected: _c0 but found:
# CSV file: file:///Users/anuragsangem/Desktop/Prepared%20MS%20University%20Data_Filtered.csv
# 23/04/28 01:28:25 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Major, researchExp, industryExp, toeflScore, GRE_V, GRE_Q, GRE_AWA, CGPA, University
# ...

# %%
# create a dataframe with input values for prediction
data = [(5, 100, 320)]
df = spark.createDataFrame(data, ["researchExp", "toeflScore", "GRE_Total"])

# transform the input dataframe to get predictions
predictions = model.transform(df)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Input In [122], in <cell line: 6>()
#       3 df = spark.createDataFrame(data, ["researchExp", "toeflScore", "GRE_Total"])
#       5 # transform the input dataframe to get predictions
# ----> 6 predictions = model.transform(df)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/ml/base.py:262, in Transformer.transform(self, dataset, params)
#     260         return self.copy(params)._transform(dataset)
#     261     else:
# --> 262         return self._transform(dataset)
#     263 else:
#     264     raise TypeError("Params must be a param map but got %s." % type(params))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/ml/pipeline.py:304, in PipelineModel._transform(self, dataset)
#     302 def _transform(self, dataset: DataFrame) -> DataFrame:
#     303     for t in self.stages:
# ...

# %%
test_data = [5.5, 100, 320]
# Create a VectorAssembler to combine the input features
assembler = VectorAssembler(
    inputCols=["researchExp", "toeflScore", "GRE_Total"],
    outputCol="features")

# Transform the test data using the VectorAssembler
test_data = assembler.transform(test_data)

# Make predictions on the test data
predictions = model.transform(test_data)

# %%
#Knn test in python

# %% [markdown]
# ## HHEERREEE

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import NearestNeighbors
import numpy as np
from joblib import Parallel, delayed
from sklearn.model_selection import train_test_split

# %%
df_filtered = pd.read_csv(r"Desktop/Prepared MS University Data_Filtered.csv")

# %%
df_filtered.head()
# Out:
#    Unnamed: 0             Major  researchExp  industryExp  toeflScore  GRE_V  \
# 0         459  Computer Science          0.0          0.0       113.0    148
# 1         461  Computer Science          0.0          0.0       117.0    160
# 2         463  Computer Science          0.0          0.0       111.0    154
# 3         468  Computer Science          0.0          0.0       106.0    147
# 4         476  Computer Science          6.0         24.0       114.0    166
#
#    GRE_Q  GRE_AWA  CGPA                         University
# 0    170      4.5  3.26  University of Wisconsin - Madison
# 1    170      5.5  3.87  University of Wisconsin - Madison
# 2    161      3.5  3.62  University of Wisconsin - Madison
# 3    163      3.5  3.68  University of Wisconsin - Madison
# 4    170      4.5  3.81  University of Wisconsin - Madison

# %%
df_filtered.columns
# Out:
# Index(['Unnamed: 0', 'Major', 'researchExp', 'industryExp', 'toeflScore',
#        'GRE_V', 'GRE_Q', 'GRE_AWA', 'CGPA', 'University'],
#       dtype='object')

# %%
df_filtered['GRE_Total']=df_filtered['GRE_V']+df_filtered['GRE_Q']
df_filtered['CGPA']=(df_filtered['CGPA']*10)/4

# %%
df_filtered.head()
# Out:
#    Unnamed: 0             Major  researchExp  industryExp  toeflScore  GRE_V  \
# 0         459  Computer Science          0.0          0.0       113.0    148
# 1         461  Computer Science          0.0          0.0       117.0    160
# 2         463  Computer Science          0.0          0.0       111.0    154
# 3         468  Computer Science          0.0          0.0       106.0    147
# 4         476  Computer Science          6.0         24.0       114.0    166
#
#    GRE_Q  GRE_AWA   CGPA                         University  GRE_Total
# 0    170      4.5  8.150  University of Wisconsin - Madison        318
# 1    170      5.5  9.675  University of Wisconsin - Madison        330
# 2    161      3.5  9.050  University of Wisconsin - Madison        315
# 3    163      3.5  9.200  University of Wisconsin - Madison        310
# 4    170      4.5  9.525  University of Wisconsin - Madison        336

# %%
required_features = ["researchExp","toeflScore","GRE_Total","CGPA","University"]
df_filtered=df_filtered[required_features]

# %%
def filter50plus(x):
    top_accepted_df = x.copy()
    univ_counts = top_accepted_df['University'].value_counts()
    top_univs = univ_counts[univ_counts > 100].index
    top_accepted_df = top_accepted_df[top_accepted_df['University'].isin(top_univs)]
    return top_accepted_df

df_filtered = filter50plus(df_filtered)

print((df_filtered['University'].nunique()), len(df_filtered['University']))
# print(len(df_filtered))

from sklearn.model_selection import train_test_split
X = df_filtered.drop("University", axis=1)
y = df_filtered["University"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
# Out:
# 40 17837

# %%
df_filtered.head()
# Out:
#    researchExp  toeflScore  GRE_Total   CGPA  \
# 0          0.0       113.0        318  8.150
# 1          0.0       117.0        330  9.675
# 2          0.0       111.0        315  9.050
# 3          0.0       106.0        310  9.200
# 4          6.0       114.0        336  9.525
#
#                           University
# 0  University of Wisconsin - Madison
# 1  University of Wisconsin - Madison
# 2  University of Wisconsin - Madison
# 3  University of Wisconsin - Madison
# 4  University of Wisconsin - Madison

# %%
df_filtered.to_csv(r'/Users/anuragsangem/Desktop/df_filtered.csv')

# %%
df_filtered
# Out:
#        researchExp  toeflScore  GRE_Total   CGPA  \
# 0              0.0  113.000000        318  8.150
# 1              0.0  117.000000        330  9.675
# 2              0.0  111.000000        315  9.050
# 3              0.0  106.000000        310  9.200
# 4              6.0  114.000000        336  9.525
# ...            ...         ...        ...    ...
# 17832          0.0  100.000000        298  8.325
# 17833          1.0  104.212515        320  8.800
# 17834          0.0  114.000000        318  8.875
# 17835         10.0  119.000000        308  9.600
# 17836         10.0  119.000000        308  9.600
#
#                                        University
# 0               University of Wisconsin - Madison
# 1               University of Wisconsin - Madison
# 2               University of Wisconsin - Madison
# 3               University of Wisconsin - Madison
# 4               University of Wisconsin - Madison
# ...                                           ...
# ...

# %%
df_filtered.isnull().sum()
# Out:
# researchExp    0
# toeflScore     0
# GRE_Total      0
# CGPA           0
# University     0
# dtype: int64

# %%
weights = {
    "CGPA": 0.3,
    "GRE_Total": 0.3,
    "toeflScore": 0.2,
    "researchExp": 0.1
}

# %%
def run_knn(weights, data, test_data, df):
    data_scaled = data.copy(deep=True)
    for feature in weights:
        data_scaled[feature] = data_scaled[feature] * weights[feature]

    k = 5 # number of nearest neighbors
    model = NearestNeighbors(n_neighbors=k+1)  
    model.fit(data_scaled)


    test_data_scaled = test_data.copy(deep=True)
    for feature in weights:
        test_data_scaled[feature] = test_data_scaled[feature] * weights[feature]
    distances, indices = model.kneighbors(test_data_scaled)

    universities = []
    for i in range(len(test_data)):
        row_indices = indices[i]  # exclude the first neighbor (itself)
        if len(row_indices) < k:
            # Skip this test point if there are less than k neighbors
            universities.append([])
            continue
        row_distances = distances[i]  # exclude the first neighbor (itself)
        #print("distances:", row_distances)
        #print("indices:", row_indices)
        weighted_distances = 1 / (row_distances ** 2)  # apply weights to the distances
        weighted_distances[~np.isfinite(weighted_distances)] = 1e10  # replace inf and -inf with a large number
        weighted_indices = [(j, weighted_distances[np.where(row_indices == j)[0][0]]) for j in row_indices]
        #print("Weighted indices:", weighted_indices,)
        university_scores = {}
        for j, w in weighted_indices:
            university = df.loc[j, "University"]
            if university in university_scores:
                university_scores[university] += w
            else:
                university_scores[university] = w
        top_universities = sorted(university_scores.items(), key=lambda x: x[1], reverse=True)[:5]
        top_universities = [u[0] for u in top_universities]
        universities.append(top_universities)
    # Return the recommended universities
    return distances, indices, universities

# %%
distances, indices, results = run_knn(weights, X_train, X_test,df_filtered)
# Out:
# /var/folders/j2/qrfkkpz51h7fdg0g8v5r67p80000gn/T/ipykernel_73000/612659071.py:26: RuntimeWarning: divide by zero encountered in true_divide
#   weighted_distances = 1 / (row_distances ** 2)  # apply weights to the distances

# %%
def validate(y_test, results):
    if len(y_test) != len(results):
        return "Length of outputs is not equal"
    correct = 0.0
    for i, val in enumerate(y_test):
        if val in results[i]:
            correct += 1
    return correct/float(len(y_test))

validation_score = validate(y_test, results)
print("Validation Score: ", validation_score)
# Out:
# Validation Score:  0.20179372197309417

# %%
cgpa = 8
GRE_Total = 320
toefl = 130
researchExp = 2
testPoint = pd.DataFrame({"researchExp": researchExp,"toeflScore": toefl, "GRE_Total": GRE_Total, "CGPA": cgpa}, index=[0])

distances, indices, results = run_knn(weights, X_train, testPoint,df_filtered)
results
# Out:
# [['State University of New York at Buffalo',
#   'University of Texas at Dallas',
#   'Syracuse University',
#   'University of Florida',
#   'New Jersey Institute of Technology']]

# %%
distances
# Out:
# array([[0.13862179, 0.13862179, 0.13862179, 0.15505564, 0.15505564,
#         0.15505564]])

# %%
indices
# Out:
# array([[ 9526, 13959, 12198, 11042, 11911,  2395]])
